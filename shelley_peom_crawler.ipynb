# %% [markdown]
# Recently,a movie called "alien covenant" caught a lot of people's eye. Just as a reviewer puts it-sci-fi meets classic literature in 'Alien: Covenant', this sci-fi film mixed itself with multiple classical literature elements to distinguish itself from other sci-fi films.
#
# These literature elements brought the film some aroma of exotic spices and impressed me a lot. And the one intrigues me most comes from the scence where the robot David cited a Shelley's poem --"Look on my works, ye Mighty, and despair". Though , David didn't mention that he want to become the king of the king, what he did was self-evident.
#
# While David praises Shelley's poem as remarkable, I am somewhat puzzled. If David was so creative,at least he himself thought so, Shouldn't he produce an original masterpiece by himself rather than recite Shelley's.
#
# Well, this is something deep learning can exzactly do, without further ado, let's make an AI to do just that-- create a new Shelley's style poem. Even the AI I created is not as powerfull as David,at least, it creates a poem better than he can do.
#
# Here is the plan I come about
#
# First, I need to get all the poems written by Shelley.
#
# Then, I'll use the RNN Neural Network with LSTM to train the data
#
# Lastly, with saved parameters, I can create as many poems as possible
#
#
# First, I crawled all Shelley's peoms from a website. The website contains 327 poems written by Shelley and the crawling process went smoothly. In a few minutes , all poems were downloaded.
#
# The next thing to do is to use a RNN architecture to train the AI. the training process also went smoothly.
#
# Here is a piece of poem written by AI, see, it wasn't that bad after all, at least, it surpasses mine.
#
#
# then,
# fraud then thou,
# but more dear to life,
# as from the spirit's wilderness,
# the thick which thou withered,
# for the song,
# when the moon is awakened,
# the flood is buried,
# but gentle gentle was slumber thus in her grave.
# there is a reward of clouds, and the swallow the water fell.
# the coursers springs of the soul it was too.
# then shrinks back, and i cry about to know that others fall,
# knows by looks,
# we moulded in mountains.
# but like shadow after friends and filled with thine own sway;-- from the earth’s waves are shaken,
# the nations & sorrows not the speed of bacchus,
# in the blood of the ocean cling,
# with living green and black both. though far bringing, and when i feeble, i think i arose the night the eyes, like wrecks,
# in the surge of heaven, where high once lighted green the red shades down in clear up in the place of the unfathomable ocean,
# night in the eden of one fair dew,
# two by pain

# %% [markdown]
# Here is how I created the ID iteration webcrawler to fetch all the tittle and its hyperlinks, after that, for  each crawled link, I'll catch the linked poem and download it into the text file.

# %%
import urllib.request
import re
from urllib.error import URLError, HTTPError, ContentTooShortError
from urllib.parse import urljoin
from urllib.parse import urlparse
import time

# %%
def download(url, user_agent='wswp', num_retries=4, charset='utf-8', proxy=None):
    """ Download a given URL and return the page content
        args:
            url (str): URL
        kwargs:
            user_agent (str): user agent (default: wswp)
            charset (str): charset if website does not include one in headers
            proxy (str): proxy url, ex 'http://IP' (default: None)
            num_retries (int): number of retries if a 5xx error is seen (default: 2)
    """
    print('Downloading:', url)
    request = urllib.request.Request(url)
    request.add_header('User-agent', user_agent)
    try:
        if proxy:
            proxy_support = urllib.request.ProxyHandler({'http': proxy})
            opener = urllib.request.build_opener(proxy_support)
            urllib.request.install_opener(opener)
        resp = urllib.request.urlopen(request)
        cs = resp.headers.get_content_charset()
        if not cs:
            cs = charset
        html = resp.read().decode(cs)
    except (URLError, HTTPError, ContentTooShortError) as e:
        print('Download error:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                # recursively retry 5xx HTTP errors
                return download(url, num_retries - 1)
    return html

import itertools 
from bs4 import BeautifulSoup as bs

def crawl_site(url):

    titles=[]
    linked_address = []
    for page in itertools.count(1): 
        if page > 9:
            break
        pg_url = '{}{}{}'.format(url, page,'/?a=a&l=3&y=') 
        html = download(pg_url) 
        if html is None:
            break 
        soup = bs(html,'html5lib')
        lik = soup.find_all('td',attrs={'class':'title'})
        
        table = soup.find('table',attrs ={'class':'poems'})
        h_links = table.find_all('a',href=True)
        tittle = [(t.text) for t in lik]
        
        r_link = [t.get('href') for t in h_links]
        linked_address.append(r_link)
        titles.append(tittle)


    return titles,linked_address

# %%
all_tittles,linked_address = crawl_site('https://www.poemhunter.com/percy-bysshe-shelley/poems/page-')
# Out:
# Downloading: https://www.poemhunter.com/percy-bysshe-shelley/poems/page-1/?a=a&l=3&y=
# Downloading: https://www.poemhunter.com/percy-bysshe-shelley/poems/page-2/?a=a&l=3&y=
# Downloading: https://www.poemhunter.com/percy-bysshe-shelley/poems/page-3/?a=a&l=3&y=
# Downloading: https://www.poemhunter.com/percy-bysshe-shelley/poems/page-4/?a=a&l=3&y=
# Downloading: https://www.poemhunter.com/percy-bysshe-shelley/poems/page-5/?a=a&l=3&y=
# Downloading: https://www.poemhunter.com/percy-bysshe-shelley/poems/page-6/?a=a&l=3&y=
# Downloading: https://www.poemhunter.com/percy-bysshe-shelley/poems/page-7/?a=a&l=3&y=
# Downloading: https://www.poemhunter.com/percy-bysshe-shelley/poems/page-8/?a=a&l=3&y=
# Downloading: https://www.poemhunter.com/percy-bysshe-shelley/poems/page-9/?a=a&l=3&y=

# %%
t = [x for tit in all_tittles for x in tit]
h = [x for tit in linked_address for x in tit]
t = [x[11:-10] for x in t]

# %%
def abs_links(start_url,all_links):
    abslinks=[]
    for link in all_links:
        abs_link = start_url+link
        abslinks.append(abs_link)
    return abslinks

# %%
starturl = 'https://www.poemhunter.com'

abslinks = abs_links(starturl,h)

# %%
def get_poems(urls):
    poems=[]
    for url in urls: 
        html = download(url) 
        print("{}".format(urls.index(url)/len(urls)),"are completed")
        if html is None: 
            break 
        soup = bs(html,'html5lib')
        lik = soup.find('div',attrs={'class':'KonaBody'})
        poem = lik.find('p').text
        poems.append(poem)
    return poems

# %%
all_poem = get_poems(abslinks)
# Out:
# Downloading: https://www.poemhunter.com/poem/the-retrospect-cwm-elan-1812/
# Downloading: https://www.poemhunter.com/poem/to-sophia-miss-stacey/
# Downloading: https://www.poemhunter.com/poem/to-the-lord-chancellor/
# Downloading: https://www.poemhunter.com/poem/the-sepulchre-of-memory/
# Downloading: https://www.poemhunter.com/poem/to-edward-williams/
# Downloading: https://www.poemhunter.com/poem/to-harriet-it-is-not-blasphemy-to-hope-that-heaven/
# Downloading: https://www.poemhunter.com/poem/from-laon-and-cythna-or-the-revolution-of-the-golden-city/
# Downloading: https://www.poemhunter.com/poem/to-harriet/
# Downloading: https://www.poemhunter.com/poem/dark-spirit-of-the-desart-rude/
# Downloading: https://www.poemhunter.com/poem/the-wandering-jew-s-soliloquy/
# Downloading: https://www.poemhunter.com/poem/to-mary-16/
# Downloading: https://www.poemhunter.com/poem/the-tower-of-famine/
# Downloading: https://www.poemhunter.com/poem/the-zucca/
# Downloading: https://www.poemhunter.com/poem/the-rude-wind-is-singing/
# Downloading: https://www.poemhunter.com/poem/the-viewless-and-invisible-consequence/
# Downloading: https://www.poemhunter.com/poem/to-mary-who-died-in-this-opinion/
# Downloading: https://www.poemhunter.com/poem/the-spectral-horseman/
# Downloading: https://www.poemhunter.com/poem/the-pine-forest-of-the-cascine-near-pisa/
# Downloading: https://www.poemhunter.com/poem/to-emilia-viviani/
# Downloading: https://www.poemhunter.com/poem/to-mary-4/
# Downloading: https://www.poemhunter.com/poem/to-constantia/
# Downloading: https://www.poemhunter.com/poem/to-italy/
# Downloading: https://www.poemhunter.com/poem/to-mary-shelley/
# Downloading: https://www.poemhunter.com/poem/to-i-fear-thy-kisses-gentle-maiden/
# Downloading: https://www.poemhunter.com/poem/to-ireland-2/
# Downloading: https://www.poemhunter.com/poem/to-mary-wollstonecraft-godwin/
# Downloading: https://www.poemhunter.com/poem/to-constantia-singing/
# Downloading: https://www.poemhunter.com/poem/the-world-s-wanderers/
# Downloading: https://www.poemhunter.com/poem/to-one-word-is-too-often-profaned/
# Downloading: https://www.poemhunter.com/poem/to-oh-there-are-spirits-of-the-air/
# Downloading: https://www.poemhunter.com/poem/the-woodman-and-the-nightingale/
# Downloading: https://www.poemhunter.com/poem/to-ianthe/
# Downloading: https://www.poemhunter.com/poem/to-death-8/
# Downloading: https://www.poemhunter.com/poem/the-past-57/
# Downloading: https://www.poemhunter.com/poem/to-jane-the-keen-stars-were-twinkling/
# Downloading: https://www.poemhunter.com/poem/unrisen-splendour-of-the-brightest-sun/
# Downloading: https://www.poemhunter.com/poem/the-sensitive-plant/
# Downloading: https://www.poemhunter.com/poem/to-jane-the-recollection/
# Downloading: https://www.poemhunter.com/poem/the-sunset-18/
# Downloading: https://www.poemhunter.com/poem/ugolino/
# Downloading: https://www.poemhunter.com/poem/the-solitary-3/
# Downloading: https://www.poemhunter.com/poem/to-the-republicans-of-north-america/
# Downloading: https://www.poemhunter.com/poem/to-a-star/
# Downloading: https://www.poemhunter.com/poem/to-morrow-3/
# Downloading: https://www.poemhunter.com/poem/to-william-shelley-3/
# Downloading: https://www.poemhunter.com/poem/to-william-shelley-thy-little-footsteps-on-the-sands/
# Downloading: https://www.poemhunter.com/poem/the-first-canzone-of-the-convito/
# Downloading: https://www.poemhunter.com/poem/stanza-from-a-translation-of-the-marseillaise-hymn/
# Downloading: https://www.poemhunter.com/poem/i-stood-upon-a-heaven-cleaving-turret/
# Downloading: https://www.poemhunter.com/poem/stanza-written-at-bracknell/
# Downloading: https://www.poemhunter.com/poem/methought-i-was-a-billow-in-the-crowd/
# Downloading: https://www.poemhunter.com/poem/to-william-shelley/
# Downloading: https://www.poemhunter.com/poem/song-to-harriet-2/
# Downloading: https://www.poemhunter.com/poem/sonnet-from-the-italian-of-cavalcanti/
# Downloading: https://www.poemhunter.com/poem/epigram-iii-spirit-of-plato/
# Downloading: https://www.poemhunter.com/poem/fragments-written-for-hellas/
# Downloading: https://www.poemhunter.com/poem/song-translated-from-the-german/
# Downloading: https://www.poemhunter.com/poem/fragment-yes-all-is-past/
# Downloading: https://www.poemhunter.com/poem/the-birth-place-of-pleasure/
# Downloading: https://www.poemhunter.com/poem/the-false-laurel-and-the-true/
# Downloading: https://www.poemhunter.com/poem/sonnet-from-the-italian-of-dante/
# Downloading: https://www.poemhunter.com/poem/fragment-igniculus-desiderii/
# Downloading: https://www.poemhunter.com/poem/song-from-the-wandering-jew/
# Downloading: https://www.poemhunter.com/poem/the-aziola/
# Downloading: https://www.poemhunter.com/poem/sonnet-to-byron-2/
# Downloading: https://www.poemhunter.com/poem/song-come-harriet-sweet-is-the-hour/
# Downloading: https://www.poemhunter.com/poem/melody-to-a-scene-of-former-times/
# Downloading: https://www.poemhunter.com/poem/epithalamium-another-version/
# Downloading: https://www.poemhunter.com/poem/fragment-or-the-triumph-of-conscience/
# Downloading: https://www.poemhunter.com/poem/sonnet-to-a-balloon-laden-with-knowledge/
# Downloading: https://www.poemhunter.com/poem/st-irvyne-s-tower/
# Downloading: https://www.poemhunter.com/poem/fragment-omens/
# Downloading: https://www.poemhunter.com/poem/fragment-from-the-wandering-jew/
# Downloading: https://www.poemhunter.com/poem/fragment-to-the-people-of-england/
# Downloading: https://www.poemhunter.com/poem/stanza/
# Downloading: https://www.poemhunter.com/poem/stanzas-april-1814/
# Downloading: https://www.poemhunter.com/poem/fragment-my-head-is-wild-with-weeping/
# Downloading: https://www.poemhunter.com/poem/fragment-great-spirit/
# Downloading: https://www.poemhunter.com/poem/lines-far-far-away-o-ye/
# Downloading: https://www.poemhunter.com/poem/the-fugitives-2/
# Downloading: https://www.poemhunter.com/poem/fiordispina/
# Downloading: https://www.poemhunter.com/poem/epigram-ii-kissing-helena/
# Downloading: https://www.poemhunter.com/poem/fragment-what-men-gain-fairly/
# Downloading: https://www.poemhunter.com/poem/song-to-harriet/
# Downloading: https://www.poemhunter.com/poem/epigram-iv-circumstance/
# Downloading: https://www.poemhunter.com/poem/fragments-supposed-to-be-parts-of-otho/
# Downloading: https://www.poemhunter.com/poem/marianne-s-dream/
# Downloading: https://www.poemhunter.com/poem/fragment-to-a-friend-released-from-prison/
# Downloading: https://www.poemhunter.com/poem/marenghi/
# Downloading: https://www.poemhunter.com/poem/from-vergil-s-fourth-georgic/
# Downloading: https://www.poemhunter.com/poem/fragment-follow-to-the-deep-wood-s-weeds/
# Downloading: https://www.poemhunter.com/poem/fragment-of-the-elegy-on-the-death-of-bion/
# Downloading: https://www.poemhunter.com/poem/fragment-a-gentle-story-of-two-lovers-young/
# Downloading: https://www.poemhunter.com/poem/epipsychidion-passages-of-the-poem-or-connected-therewith/
# Downloading: https://www.poemhunter.com/poem/the-isle-2/
# Downloading: https://www.poemhunter.com/poem/the-cyclops/
# Downloading: https://www.poemhunter.com/poem/fragment-such-hope-as-is-the-sick-despair-of-good/
# Downloading: https://www.poemhunter.com/poem/lines-to-a-reviewer/
# Downloading: https://www.poemhunter.com/poem/epithalamium-3/
# Downloading: https://www.poemhunter.com/poem/sonnet-ye-hasten-to-the-grave/
# Downloading: https://www.poemhunter.com/poem/the-deserts-of-dim-sleep/
# Downloading: https://www.poemhunter.com/poem/epigram-i-to-stella/
# Downloading: https://www.poemhunter.com/poem/when-a-lover-clasps-his-fairest/
# Downloading: https://www.poemhunter.com/poem/from-the-original-draft-of-the-poem-to-william-shelley/
# Downloading: https://www.poemhunter.com/poem/the-drowned-lover/
# Downloading: https://www.poemhunter.com/poem/on-the-dark-height-of-jura/
# Downloading: https://www.poemhunter.com/poem/dirge-for-the-year/
# Downloading: https://www.poemhunter.com/poem/sonnet-on-launching-some-bottles-filled-with-knowledge-into-the-bristol-channel/
# Downloading: https://www.poemhunter.com/poem/from-vergil-s-tenth-eclogue/
# Downloading: https://www.poemhunter.com/poem/matilda-gathering-flowers/
# Downloading: https://www.poemhunter.com/poem/fragment-to-one-singing/
# Downloading: https://www.poemhunter.com/poem/the-death-knell-is-ringing/
# Downloading: https://www.poemhunter.com/poem/fragment-ye-gentle-visitations-of-calm-thought/
# Downloading: https://www.poemhunter.com/poem/buona-notte-2/
# Downloading: https://www.poemhunter.com/poem/the-devil-s-walk-a-ballad/
# Downloading: https://www.poemhunter.com/poem/song-translated-from-the-italian/
# Downloading: https://www.poemhunter.com/poem/song-sorrow/
# Downloading: https://www.poemhunter.com/poem/fragment-of-a-sonnet-to-harriet/
# Downloading: https://www.poemhunter.com/poem/written-at-bracknell/
# Downloading: https://www.poemhunter.com/poem/lines-to-a-critic/
# Downloading: https://www.poemhunter.com/poem/fragment-sufficient-unto-the-day/
# Downloading: https://www.poemhunter.com/poem/fromthe-arabic-an-imitation/
# Downloading: https://www.poemhunter.com/poem/to-yet-look-on-me/
# Downloading: https://www.poemhunter.com/poem/from-the-greek-of-moschus/
# Downloading: https://www.poemhunter.com/poem/from-the-greek-of-moschus-pan-loved-his-neighbour-echo/
# Downloading: https://www.poemhunter.com/poem/fragment-of-a-sonnet-farewell-to-north-devon/
# Downloading: https://www.poemhunter.com/poem/lines-that-time-is-dead-for-ever-child/
# Downloading: https://www.poemhunter.com/poem/the-cenci-a-tragedy-in-five-acts/
# Downloading: https://www.poemhunter.com/poem/queen-mab-part-vii/
# Downloading: https://www.poemhunter.com/poem/fragment-milton-s-spirit/
# Downloading: https://www.poemhunter.com/poem/sister-rosa-a-ballad/
# Downloading: https://www.poemhunter.com/poem/fragment-of-a-satire-on-satire/
# Downloading: https://www.poemhunter.com/poem/queen-mab-part-v/
# Downloading: https://www.poemhunter.com/poem/on-a-fete-at-carlton-house-fragment/
# Downloading: https://www.poemhunter.com/poem/homer-s-hymn-to-venus/
# Downloading: https://www.poemhunter.com/poem/the-boat-on-the-serchio/
# Downloading: https://www.poemhunter.com/poem/song-cold-cold-is-the-blast-when-december-is-howling/
# Downloading: https://www.poemhunter.com/poem/prince-athanase/
# Downloading: https://www.poemhunter.com/poem/evening-to-harriet/
# Downloading: https://www.poemhunter.com/poem/letter-to-maria-gisborne/
# Downloading: https://www.poemhunter.com/poem/to-the-nile-2/
# Downloading: https://www.poemhunter.com/poem/saint-edmond-s-eve/
# Downloading: https://www.poemhunter.com/poem/on-an-icicle-that-clung-to-the-grass-of-a-grave/
# Downloading: https://www.poemhunter.com/poem/on-robert-emmet-s-grave/
# Downloading: https://www.poemhunter.com/poem/fragment-the-vine-shroud/
# Downloading: https://www.poemhunter.com/poem/fragment-there-is-a-warm-and-gentle-atmosphere/
# Downloading: https://www.poemhunter.com/poem/lines-written-during-the-castlereagh-administration/
# Downloading: https://www.poemhunter.com/poem/fragment-wedded-souls/
# Downloading: https://www.poemhunter.com/poem/sonnet-england-in-1819/
# Downloading: https://www.poemhunter.com/poem/fragment-the-lake-s-margin/
# Downloading: https://www.poemhunter.com/poem/song-fierce-roars-the-midnight-storm/
# Downloading: https://www.poemhunter.com/poem/i-would-not-be-a-king/
# Downloading: https://www.poemhunter.com/poem/fragment-to-byron/
# Downloading: https://www.poemhunter.com/poem/rome-and-nature/
# Downloading: https://www.poemhunter.com/poem/may-the-limner/
# Downloading: https://www.poemhunter.com/poem/wine-of-the-fairies/
# Downloading: https://www.poemhunter.com/poem/song-for-tasso/
# Downloading: https://www.poemhunter.com/poem/fragments-of-an-unfinished-drama/
# Downloading: https://www.poemhunter.com/poem/homer-s-hymn-to-castor-and-pollux/
# Downloading: https://www.poemhunter.com/poem/orpheus-8/
# Downloading: https://www.poemhunter.com/poem/on-the-medusa-of-leonardo-da-vinci-in-the-florentine-gallery/
# Downloading: https://www.poemhunter.com/poem/similes-for-two-political-characters-of-1819/
# Downloading: https://www.poemhunter.com/poem/zephyrus-the-awakener/
# Downloading: https://www.poemhunter.com/poem/verses-on-a-cat/
# Downloading: https://www.poemhunter.com/poem/with-a-guitar-to-jane/
# Downloading: https://www.poemhunter.com/poem/ode-to-naples/
# Downloading: https://www.poemhunter.com/poem/revenge-53/
# Downloading: https://www.poemhunter.com/poem/to-the-moonbeam/
# Downloading: https://www.poemhunter.com/poem/poetical-essay/
# Downloading: https://www.poemhunter.com/poem/otho/
# Downloading: https://www.poemhunter.com/poem/liberty-19/
# Downloading: https://www.poemhunter.com/poem/stanzas-written-in-dejection-near-naples-2/
# Downloading: https://www.poemhunter.com/poem/lines-written-on-hearing-the-news-of-the-death-of-napoleon/
# Downloading: https://www.poemhunter.com/poem/bigotry-s-victim/
# Downloading: https://www.poemhunter.com/poem/mighty-eagle/
# Downloading: https://www.poemhunter.com/poem/epitaph-58/
# Downloading: https://www.poemhunter.com/poem/sonnet-political-greatness/
# Downloading: https://www.poemhunter.com/poem/life-rounded-with-sleep/
# Downloading: https://www.poemhunter.com/poem/the-magnetic-lady-to-her-patient/
# Downloading: https://www.poemhunter.com/poem/ginevra/
# Downloading: https://www.poemhunter.com/poem/evening-ponte-al-mare-pisa/
# Downloading: https://www.poemhunter.com/poem/fragment-apostrophe-to-silence/
# Downloading: https://www.poemhunter.com/poem/queen-mab-part-ix/
# Downloading: https://www.poemhunter.com/poem/fragment-what-mary-is-when-she-a-little-smiles/
# Downloading: https://www.poemhunter.com/poem/queen-mab-part-ii/
# Downloading: https://www.poemhunter.com/poem/homer-s-hymn-to-the-sun/
# Downloading: https://www.poemhunter.com/poem/fragment-home/
# Downloading: https://www.poemhunter.com/poem/fragment-is-it-that-in-some-brighter-sphere/
# Downloading: https://www.poemhunter.com/poem/i-faint-i-perish-with-my-love/
# Downloading: https://www.poemhunter.com/poem/fragment-of-a-ghost-story/
# Downloading: https://www.poemhunter.com/poem/homer-s-hymn-to-minerva/
# Downloading: https://www.poemhunter.com/poem/sonnet-lift-not-the-painted-veil-which-those-who-live/
# Downloading: https://www.poemhunter.com/poem/the-irishman-s-song/
# Downloading: https://www.poemhunter.com/poem/when-soft-winds-and-sunny-skies/
# Downloading: https://www.poemhunter.com/poem/peter-bell-the-third/
# Downloading: https://www.poemhunter.com/poem/o-that-a-chariot-of-cloud-were-mine/
# Downloading: https://www.poemhunter.com/poem/on-leaving-london-for-wales/
# Downloading: https://www.poemhunter.com/poem/queen-mab-part-iii/
# Downloading: https://www.poemhunter.com/poem/queen-mab-part-iv/
# Downloading: https://www.poemhunter.com/poem/fragment-love-the-universe-to-day/
# Downloading: https://www.poemhunter.com/poem/faint-with-love-the-lady-of-the-south/
# Downloading: https://www.poemhunter.com/poem/to-the-mind-of-man/
# Downloading: https://www.poemhunter.com/poem/and-that-i-walk-thus-proudly-crowned-withal/
# Downloading: https://www.poemhunter.com/poem/o-thou-immortal-deity/
# Downloading: https://www.poemhunter.com/poem/fragment-thoughts-come-and-go-in-solitude/
# Downloading: https://www.poemhunter.com/poem/fragment-amor-aeternus/
# Downloading: https://www.poemhunter.com/poem/fragment-a-wanderer/
# Downloading: https://www.poemhunter.com/poem/wake-the-serpent-not/
# Downloading: https://www.poemhunter.com/poem/ghasta-or-the-avenging-demon/
# Downloading: https://www.poemhunter.com/poem/homer-s-hymn-to-the-moon/
# Downloading: https://www.poemhunter.com/poem/song-despair/
# Downloading: https://www.poemhunter.com/poem/lines-we-meet-not-as-we-parted/
# Downloading: https://www.poemhunter.com/poem/on-keats-who-desired-that-on-his-tomb-should-be-inscribed/
# Downloading: https://www.poemhunter.com/poem/on-fanny-godwin/
# Downloading: https://www.poemhunter.com/poem/music-and-sweet-poetry/
# Downloading: https://www.poemhunter.com/poem/love-s-rose-2/
# Downloading: https://www.poemhunter.com/poem/homer-s-hymn-to-the-earth-mother-of-all/
# Downloading: https://www.poemhunter.com/poem/hymn-of-apollo/
# Downloading: https://www.poemhunter.com/poem/love-1799/
# Downloading: https://www.poemhunter.com/poem/war-221/
# Downloading: https://www.poemhunter.com/poem/summer-and-winter-2/
# Downloading: https://www.poemhunter.com/poem/invocation-to-misery/
# Downloading: https://www.poemhunter.com/poem/death-in-life/
# Downloading: https://www.poemhunter.com/poem/an-ode-written-october-1819-before-the-spaniards-had-recovered-their-liberty/
# Downloading: https://www.poemhunter.com/poem/to-the-queen-of-my-heart/
# Downloading: https://www.poemhunter.com/poem/remembrance-50/
# Downloading: https://www.poemhunter.com/poem/here-i-sit-with-my-paper/
# Downloading: https://www.poemhunter.com/poem/pater-omnipotens/
# Downloading: https://www.poemhunter.com/poem/another-fragment-to-music/
# Downloading: https://www.poemhunter.com/poem/fragment-satan-broken-loose/
# Downloading: https://www.poemhunter.com/poem/ode-to-heaven/
# Downloading: https://www.poemhunter.com/poem/beauty-s-halo/
# Downloading: https://www.poemhunter.com/poem/song-hope/
# Downloading: https://www.poemhunter.com/poem/lines-written-in-the-bay-of-lerici/
# Downloading: https://www.poemhunter.com/poem/death-515/
# Downloading: https://www.poemhunter.com/poem/julian-and-maddalo-excerpt/
# Downloading: https://www.poemhunter.com/poem/arethusa-2/
# Downloading: https://www.poemhunter.com/poem/mutability-ii/
# Downloading: https://www.poemhunter.com/poem/a-serpent-face/
# Downloading: https://www.poemhunter.com/poem/love-hope-desire-and-fear/
# Downloading: https://www.poemhunter.com/poem/queen-mab-part-i/
# Downloading: https://www.poemhunter.com/poem/in-horologium/
# Downloading: https://www.poemhunter.com/poem/passage-of-the-apennines/
# Downloading: https://www.poemhunter.com/poem/song-rarely-rarely-comest-thou/
# Downloading: https://www.poemhunter.com/poem/lines-2/
# Downloading: https://www.poemhunter.com/poem/song-13/
# Downloading: https://www.poemhunter.com/poem/rosalind-and-helen-a-modern-eclogue/
# Downloading: https://www.poemhunter.com/poem/from-adonais-49-52/
# Downloading: https://www.poemhunter.com/poem/on-a-faded-violet/
# Downloading: https://www.poemhunter.com/poem/lines-written-among-the-euganean-hills/
# Downloading: https://www.poemhunter.com/poem/to-coleridge/
# Downloading: https://www.poemhunter.com/poem/from-the-arabic-an-imitation/
# Downloading: https://www.poemhunter.com/poem/to-5/
# Downloading: https://www.poemhunter.com/poem/queen-mab-part-vi-excerpts/
# Downloading: https://www.poemhunter.com/poem/a-tale-of-society-as-it-is-from-facts-1811/
# Downloading: https://www.poemhunter.com/poem/epipsychidion-excerpt/
# Downloading: https://www.poemhunter.com/poem/mont-blanc-lines-written-in-the-vale-of-chamouni/
# Downloading: https://www.poemhunter.com/poem/an-allegory-3/
# Downloading: https://www.poemhunter.com/poem/the-witch-of-atlas/
# Downloading: https://www.poemhunter.com/poem/the-two-spirits-an-allegory/
# Downloading: https://www.poemhunter.com/poem/one-sung-of-thee-who-left-the-tale-untold/
# Downloading: https://www.poemhunter.com/poem/ode-to-liberty-2/
# Downloading: https://www.poemhunter.com/poem/a-roman-s-chamber/
# Downloading: https://www.poemhunter.com/poem/the-waning-moon/
# Downloading: https://www.poemhunter.com/poem/song-of-proserpine-while-gathering-flowers-on-the-plain-of-enna/
# Downloading: https://www.poemhunter.com/poem/hellas/
# Downloading: https://www.poemhunter.com/poem/the-triumph-of-life/
# Downloading: https://www.poemhunter.com/poem/a-hate-song/
# Downloading: https://www.poemhunter.com/poem/remorse/
# Downloading: https://www.poemhunter.com/poem/hymn-of-pan/
# Downloading: https://www.poemhunter.com/poem/chorus-from-hellas/
# Downloading: https://www.poemhunter.com/poem/to-wordsworth/
# Downloading: https://www.poemhunter.com/poem/time-4/
# Downloading: https://www.poemhunter.com/poem/lines-the-cold-earth-slept-below/
# Downloading: https://www.poemhunter.com/poem/time-long-past/
# Downloading: https://www.poemhunter.com/poem/a-new-national-anthem/
# Downloading: https://www.poemhunter.com/poem/the-fitful-alternations-of-the-rain/
# Downloading: https://www.poemhunter.com/poem/alas-this-is-not-what-i-thought-life-was/
# Downloading: https://www.poemhunter.com/poem/despair-77/
# Downloading: https://www.poemhunter.com/poem/the-question-2/
# Downloading: https://www.poemhunter.com/poem/invocation/
# Downloading: https://www.poemhunter.com/poem/lift-not-the-painted-veil-which-those-who-live/
# Downloading: https://www.poemhunter.com/poem/on-death/
# Downloading: https://www.poemhunter.com/poem/night-2/
# Downloading: https://www.poemhunter.com/poem/death-is-here-and-death-is-there/
# Downloading: https://www.poemhunter.com/poem/the-invitation/
# Downloading: https://www.poemhunter.com/poem/the-moon-2/
# Downloading: https://www.poemhunter.com/poem/feelings-of-a-republican-on-the-fall-of-bonapart/
# Downloading: https://www.poemhunter.com/poem/one-word-is-too-often-profaned/
# Downloading: https://www.poemhunter.com/poem/eyes-a-fragment/
# Downloading: https://www.poemhunter.com/poem/hymn-to-intellectual-beauty/
# Downloading: https://www.poemhunter.com/poem/the-mask-of-anarchy/
# Downloading: https://www.poemhunter.com/poem/prometheus-unbound-act-i-excerpt/
# Downloading: https://www.poemhunter.com/poem/fragment-to-the-moon/
# Downloading: https://www.poemhunter.com/poem/archy-s-song-from-charles-the-first-a-widow-bird-sate-mourning-for-her-love/
# Downloading: https://www.poemhunter.com/poem/asia-from-prometheus-unbound/
# Downloading: https://www.poemhunter.com/poem/to-the-moon-2/
# Downloading: https://www.poemhunter.com/poem/and-like-a-dying-lady-lean-and-pale/
# Downloading: https://www.poemhunter.com/poem/a-fragment-to-music/
# Downloading: https://www.poemhunter.com/poem/to-night/
# Downloading: https://www.poemhunter.com/poem/art-thou-pale-for-weariness/
# Downloading: https://www.poemhunter.com/poem/an-exhortation/
# Downloading: https://www.poemhunter.com/poem/england-in-1819/
# Downloading: https://www.poemhunter.com/poem/a-dirge-4/
# Downloading: https://www.poemhunter.com/poem/a-summer-evening-churchyard-lechlade-gloucesters/
# Downloading: https://www.poemhunter.com/poem/alastor-or-the-spirit-of-solitude/
# Downloading: https://www.poemhunter.com/poem/autumn-a-dirge/
# Downloading: https://www.poemhunter.com/poem/bereavement/
# Downloading: https://www.poemhunter.com/poem/a-dialogue-5/
# Downloading: https://www.poemhunter.com/poem/to-a-skylark/
# Downloading: https://www.poemhunter.com/poem/when-the-lamp-is-shattered/
# Downloading: https://www.poemhunter.com/poem/a-bridal-song/
# Downloading: https://www.poemhunter.com/poem/the-indian-serenade/
# Downloading: https://www.poemhunter.com/poem/the-cloud/
# Downloading: https://www.poemhunter.com/poem/music-when-soft-voices-die/
# Downloading: https://www.poemhunter.com/poem/i-arise-from-dreams-of-thee/
# Downloading: https://www.poemhunter.com/poem/adonais/
# Downloading: https://www.poemhunter.com/poem/to-the-men-of-england/
# Downloading: https://www.poemhunter.com/poem/mutability/
# Downloading: https://www.poemhunter.com/poem/ode-to-the-west-wind/
# Downloading: https://www.poemhunter.com/poem/a-lament/
# Downloading: https://www.poemhunter.com/poem/good-night/
# Downloading: https://www.poemhunter.com/poem/love-s-philosophy/
# Downloading: https://www.poemhunter.com/poem/ozymandias/

# %%
from string import punctuation

poems = [''.join(poem.split('\n')) for poem in all_poem]

# %%
all_text = ''
for i in poems:
    all_text += i

# %%
txet_file = open('data/poem.txt','w')
txet_file.write(all_text)
txet_file.close()

# %%
import csv
with open('data/peom.csv', 'w') as csvfile:
    spamwriter = csv.writer(csvfile)
    spamwriter.writerow(['title','content'])
    for i in range(len(t)):
        spamwriter.writerow([t[i],poems[i]])
