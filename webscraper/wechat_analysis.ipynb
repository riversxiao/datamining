# %%
import itchat
import re
import jieba
import matplotlib.pyplot as plt
from wordcloud import WordCloud, ImageColorGenerator
import os
import numpy as np
import PIL.Image as Image

# %%
article = open('text.txt').read()

# %%
import string
exclude = set(string.punctuation)
article = ''.join(ch for ch in article if ch not in exclude)
wl_space_split = article

# %%
import matplotlib.pyplot as plt
import pylab
from wordcloud import WordCloud, ImageColorGenerator
import os
import numpy as np
import PIL.Image as Image
alice_coloring = np.array(Image.open(os.path.join(d, "mask.jpg")))
wordcloud = WordCloud(max_words=20000,max_font_size=50,background_color="white",mask=alice_coloring,width=100, height=200).generate(article)
image_colors = ImageColorGenerator(alice_coloring)
plt.imshow(wordcloud.recolor(color_func=image_colors))
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
